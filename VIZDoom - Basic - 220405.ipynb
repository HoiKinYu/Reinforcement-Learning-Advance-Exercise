# %% [markdown]
# # Executive Summary
#
# I'm using the environment in the ViZDoom to practice how to train an agent by reinforcement learning. In this notebook, ***the goal of the Basic environment is to kill the monster as soon as possible***.
#
# ### Here is my key findings during the process:
#
# ***Found Project Baseline by Using Random Action*** (Section 3)
# - The ***reward received in between -365 to 66 (average -121) by taken random actions***.
#
# ***Using stable_baselines3 PPO model to train the Agent*** (Section 4)
# - The ***Mean Reward reach highest reward at 150k timesteps around 80*** (time spend 1hr 18min).
# - Compare to the average reward -121 by taking random action before learning, ***the agent perform significantly better. It killed the monster very quickly***.
#
# ### ***Table of Content:***
# 1. Configs of Doom Environment
# 2. Converting it to a Gym Environment
# 3. Found Project Baseline by Using Random Action
# 4. Using stable_baselines3 PPO model to train the Agent
# 5. Load and Test the Best Saved Agent

# %% [markdown]
# # 1. Configs of Doom Environment
#
# <img src='image/VIZDOOM_Screen.png'/>
#
# - ***Scenarios:*** Basic.cfg
# - ***Episdoe Start Time:*** 14
# - ***Episode Timeout:*** 300
# - ***Available Actions:***
#   - Move_Left  [1,0,0]
#   - Move_Right [0,1,0]
#   - Attack     [0,0,1]
# - ***Available Game Variables:*** AMMO2
# - ***Mode:*** Player
# - ***Doom Skill:*** 5
# - ***Living Reward:*** -1
#
# ##### Rendering options
# - screen_resolution = RES_320X240
# - screen_format = CRCGCB
# - render_hud = True
# - render_crosshair = false
# - render_weapon = true
# - render_decals = false
# - render_particles = false
# - window_visible = true

# %%
from vizdoom import *          # Import vizdoom for game env

import random                  # Import random from action sampling

import time                    # Import time for sleeping

import numpy as np             # Import numpy for identity matrix

# %%
# Setup game
game = DoomGame()

game.load_config('VizDoom/scenarios/basic.cfg')

game.init()

# %%
game.get_state().screen_buffer.shape                       # screen shape 240 x 320 RGB Colors
# Out:
# (3, 240, 320)

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype = np.uint8)                 # actions: Move Left[1,0,0], Move Right[0,1,0], Attack[0,0,1]

random.choice(actions)
# Out:
# array([1, 0, 0], dtype=uint8)

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.64-cp36-abi3-macosx_10_15_x86_64.whl (46.3 MB)
#      |████████████████████████████████| 46.3 MB 329 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from opencv-python) (1.22.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64

# %%
# Import Dependencies
from gym import Env                      # Import environment base class from OpenAI Gym

from gym.spaces import Discrete, Box     # Import gym spaces

import cv2                               # Import opencv

import numpy as np                       # Impoet numpy

# %%
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        
        # Inherit from Env
        super().__init__()
        
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('VizDoom/scenarios/basic.cfg')
        
        # Render frame logic
        if render == False: 
            
            self.game.set_window_visible(False)
            
        else:
            
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render = True)

# %%
env.step(0)
# Out:
# (array([[[88],
#          [75],
#          [91],
#          ...,
#          [75],
#          [89],
#          [76]],
#
#         [[53],
#          [53],
#          [50],
#          ...,
#          [45],
#          [54],
#          [53]],
#
#         [[26],
#          [26],
#          [26],
#          ...,
#          [25],
#          [35],
#          [51]],
#
#         ...,
#
#         [[75],
#          [63],
#          [62],
#          ...,
#          [44],
#          [71],
#          [60]],
#
#         [[15],
#          [48],
#          [47],
#          ...,
#          [49],
#          [69],
#          [47]],
#
#         [[22],
#          [14],
#          [26],
#          ...,
#          [57],
#          [37],
#          [39]]], dtype=uint8),
#  -4.0,
#  False,
#  {'info': 50.0})

# %%
env.close()

# %% [markdown]
# ### Check the Environment

# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-1.11.0-cp39-none-macosx_10_9_x86_64.whl (129.9 MB)
#      |████████████████████████████████| 129.9 MB 203 kB/s eta 0:00:01
# Collecting typing-extensions
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Installing collected packages: typing-extensions, torch
# Successfully installed torch-1.11.0 typing-extensions-4.1.1

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Using cached stable_baselines3-1.5.0-py3-none-any.whl (177 kB)
# Requirement already satisfied: cloudpickle in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from stable_baselines3) (2.0.0)
# Requirement already satisfied: numpy in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from stable_baselines3) (1.22.3)
# Requirement already satisfied: torch>=1.8.1 in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from stable_baselines3) (1.11.0)
# Collecting pandas
#   Downloading pandas-1.4.2-cp39-cp39-macosx_10_9_x86_64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 206 kB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp39-cp39-macosx_10_9_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 67 kB/s eta 0:00:012
# Collecting gym==0.21
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
# Requirement already satisfied: typing-extensions in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from torch>=1.8.1->stable_baselines3) (4.1.1)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.0-cp39-cp39-macosx_10_9_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 117 kB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (3.0.7)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
#      |████████████████████████████████| 65 kB 128 kB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.2-py3-none-any.whl (899 kB)
#      |████████████████████████████████| 899 kB 99 kB/s eta 0:00:011
# Requirement already satisfied: six>=1.5 in /users/hoikinyu/desktop/SelfPracticeProjects/vizdoomenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 88 kB/s eta 0:00:012
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616825 sha256=f1247be050f35477aaa803c9f5250952e737d81231cf6ac15efb8e661b0e2bfc
#   Stored in directory: /Users/hoikinyu/Library/Caches/pip/wheels/b3/50/6c/0a82c1358b4da2dbd9c1bb17e0f89467db32812ab236dbf6d5
# Successfully built gym
# Installing collected packages: pytz, pillow, kiwisolver, fonttools, cycler, pandas, matplotlib, gym, stable-baselines3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.23.1
#     Uninstalling gym-0.23.1:
#       Successfully uninstalled gym-0.23.1
# Successfully installed cycler-0.11.0 fonttools-4.31.2 gym-0.21.0 kiwisolver-1.4.2 matplotlib-3.5.1 pandas-1.4.2 pillow-9.1.0 pytz-2022.1 stable-baselines3-1.5.0

# %% [markdown]
# # 3. Found Project Baseline by Using Random Action

# %%
episodes = 10                                                 # set number of game to play

for episode in range(episodes+1):                             # loop over each of game
    
    game.new_episode()                                        # reset the game back to initial state 
    
    while not game.is_episode_finished():                     # check he game isn't done
        
        state = game.get_state()                              # get a current game state
        
        img = state.screen_buffer                             # convert current state into an image
        
        info = state.game_variables                           # the info here is number of ammo remain 
        
        reward = game.make_action(random.choice(actions), 4)  # take an random action, 4: mean skip 4 frames and then get the reward (time delay to see the bullet hit on the target or not)
        
        print('reward', reward)                               # print out reward received from last action
        
        time.sleep(0.2)                                    
        
    print('Result:', game.get_total_reward())                 # print out current total reward
    
    time.sleep(2)
# Out:
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 97.0
# Result: -153.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: 66.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: -117.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# Result: -365.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# Result: -370.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward 97.0
# Result: -7.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: -78.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: -142.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: -160.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: -34.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -9.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward -4.0
# reward 99.0
# Result: 21.0

# %%
game.close()

# %% [markdown]
# Remark:
# - The above 11 episodes showing that, the ***reward received in between -365 to 66 (average -121) by taken random actions***.

# %% [markdown]
# # 4. Using stable_baselines3 PPO model to train the Agent

# %% [markdown]
# ### Setup Callback

# %%
# Import Dependencies
import os                                                      # Import os for file nav

from stable_baselines3.common.callbacks import BaseCallback    # Import Base Callback for saving models

from stable_baselines3 import PPO                              # Import PPO for training

# %%
CHECKPOINT_DIR = './train/DOOM'                                # Save the trained model into train directory

LOG_DIR = './logs/DOOM'                                        # Save the log into log directory

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        
        super(TrainAndLoggingCallback, self).__init__(verbose)
        
        self.check_freq = check_freq
        
        self.save_path = save_path

    def _init_callback(self):
        
        if self.save_path is not None:
            
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        
        if self.n_calls % self.check_freq == 0:
            
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            
            self.model.save(model_path)

        return True

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq = 500000, save_path=CHECKPOINT_DIR)   # save the model for every 500000 steps

# %%
# Non rendered environment
env = VizDoomGym()

PPO_model = PPO('CnnPolicy',
            env,
            tensorboard_log = LOG_DIR, 
            verbose = 1, 
            learning_rate = 0.0001,
            n_steps = 4096                  # 4096 here means that 4096 sets of observations, 
                                            # actions, log probabilities & values will be stored in the buffer for one iteration 
           )
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
PPO_model.learn(total_timesteps=1000000,    # 1 million 
            callback=callback
           )
# Out:
# Logging to ./logs/DOOM/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -175     |
# | time/              |          |
# |    fps             | 242      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.3        |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 2           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008129916 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 5.14e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00677     |
# |    value_loss           | 1.9e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.6       |
# |    ep_rew_mean          | -163       |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 3          |
# |    time_elapsed         | 278        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01022633 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.088      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 938        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00248   |
# |    value_loss           | 2.23e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.5        |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 4           |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010424374 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00276     |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.8        |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 5           |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009419005 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 989         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 2.01e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.5         |
# |    ep_rew_mean          | -127         |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 6            |
# |    time_elapsed         | 668          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0095987525 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 946          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 2e+03        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.9        |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 7           |
# |    time_elapsed         | 798         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017906029 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 454         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.9       |
# |    ep_rew_mean          | -133       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 8          |
# |    time_elapsed         | 932        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01877732 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.892     |
# |    explained_variance   | 0.753      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.18e+03   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00242   |
# |    value_loss           | 2.04e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.3        |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 9           |
# |    time_elapsed         | 1063        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021592401 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 655         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 2.84e-05    |
# |    value_loss           | 1.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | -75.4       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 10          |
# |    time_elapsed         | 1191        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014724538 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 425         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00293     |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.4        |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 11          |
# |    time_elapsed         | 1318        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009580939 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 768         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0031      |
# |    value_loss           | 1.7e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.9       |
# |    ep_rew_mean          | -116       |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 12         |
# |    time_elapsed         | 1447       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00811898 |
# |    clip_fraction        | 0.0917     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.678     |
# |    explained_variance   | 0.685      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.58e+03   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.00117    |
# |    value_loss           | 2.42e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.8        |
# |    ep_rew_mean          | -89.5       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 13          |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008979126 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 974         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00161     |
# |    value_loss           | 2.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.3        |
# |    ep_rew_mean          | -73.9       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 14          |
# |    time_elapsed         | 1707        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017035916 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 933         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.000767    |
# |    value_loss           | 1.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32          |
# |    ep_rew_mean          | -79.4       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 15          |
# |    time_elapsed         | 1839        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012101217 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00125     |
# |    value_loss           | 2.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | -16.8       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 16          |
# |    time_elapsed         | 1968        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011213732 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 401         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00241     |
# |    value_loss           | 1.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | -31.9       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 17          |
# |    time_elapsed         | 2099        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014359905 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 408         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00233     |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | -35.4       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 18          |
# |    time_elapsed         | 2230        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016186558 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 318         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 1.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | 26.7        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 19          |
# |    time_elapsed         | 2361        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.021043343 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 823         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00358     |
# |    value_loss           | 1.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 38          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 20          |
# |    time_elapsed         | 2493        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.020132748 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 280         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 21          |
# |    time_elapsed         | 2624        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.017433833 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 765         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 1.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.97        |
# |    ep_rew_mean          | 68.5        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 22          |
# |    time_elapsed         | 2756        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.020615736 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 310         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 994         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.57        |
# |    ep_rew_mean          | 58.2        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 23          |
# |    time_elapsed         | 2886        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.042899497 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 240         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000179    |
# |    value_loss           | 397         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.9       |
# |    ep_rew_mean          | 73.3      |
# | time/                   |           |
# |    fps                  | 32        |
# |    iterations           | 24        |
# |    time_elapsed         | 3017      |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0165349 |
# |    clip_fraction        | 0.139     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.491    |
# |    explained_variance   | 0.905     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 597       |
# |    n_updates            | 230       |
# |    policy_gradient_loss | 0.00375   |
# |    value_loss           | 536       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.94       |
# |    ep_rew_mean          | 73.6       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 25         |
# |    time_elapsed         | 3149       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.04358363 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.404     |
# |    explained_variance   | 0.371      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 107        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.00771    |
# |    value_loss           | 160        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.64       |
# |    ep_rew_mean          | 79.9       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 26         |
# |    time_elapsed         | 3280       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.04213395 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.333     |
# |    explained_variance   | 0.454      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 85.3       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0057     |
# |    value_loss           | 171        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.58        |
# |    ep_rew_mean          | 75.5        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 27          |
# |    time_elapsed         | 3412        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.028283728 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.306      |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.6        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0329      |
# |    value_loss           | 77.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.61        |
# |    ep_rew_mean          | 75.9        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 28          |
# |    time_elapsed         | 3545        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.023477726 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00981     |
# |    value_loss           | 81.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.83        |
# |    ep_rew_mean          | 79.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 29          |
# |    time_elapsed         | 3677        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.018809706 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00659     |
# |    value_loss           | 58.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.36        |
# |    ep_rew_mean          | 76.7        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 30          |
# |    time_elapsed         | 3811        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.012250548 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.177      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0193      |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.9         |
# |    ep_rew_mean          | 79          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 31          |
# |    time_elapsed         | 3944        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.020463418 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.151      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 31.8        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00806     |
# |    value_loss           | 34          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.72        |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 32          |
# |    time_elapsed         | 4077        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.023618035 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.126      |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35.4        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0146      |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.87        |
# |    ep_rew_mean          | 79          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 33          |
# |    time_elapsed         | 4210        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.016925402 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00941     |
# |    value_loss           | 29.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.73        |
# |    ep_rew_mean          | 79.6        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 34          |
# |    time_elapsed         | 4341        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.018324839 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.99        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00959     |
# |    value_loss           | 39.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34         |
# |    ep_rew_mean          | 76.9         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 35           |
# |    time_elapsed         | 4472         |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0076719383 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0939      |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 8.47         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.0165       |
# |    value_loss           | 19.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.89        |
# |    ep_rew_mean          | 79.2        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 36          |
# |    time_elapsed         | 4603        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.009717921 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0736     |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.54        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00799     |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.79        |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 37          |
# |    time_elapsed         | 4736        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.019418653 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0683     |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.19        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0135      |
# |    value_loss           | 8.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.72        |
# |    ep_rew_mean          | 79.8        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 38          |
# |    time_elapsed         | 4869        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.012434937 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0609     |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.07        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0132      |
# |    value_loss           | 14.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.81         |
# |    ep_rew_mean          | 79.6         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 39           |
# |    time_elapsed         | 5003         |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0072935633 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0556      |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.42         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00969      |
# |    value_loss           | 9.83         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.27        |
# |    ep_rew_mean          | 77.4        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 40          |
# |    time_elapsed         | 5135        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.045948148 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0522     |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 19.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00401     |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.54        |
# |    ep_rew_mean          | 80.6        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 41          |
# |    time_elapsed         | 5269        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.025296211 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0482     |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.6        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0062      |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.68        |
# |    ep_rew_mean          | 80.2        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 42          |
# |    time_elapsed         | 5404        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.015738506 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0489     |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.94        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00852     |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.58        |
# |    ep_rew_mean          | 80.4        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 43          |
# |    time_elapsed         | 5534        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.024232786 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0473     |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.91        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00631     |
# |    value_loss           | 29.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.68        |
# |    ep_rew_mean          | 79.9        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 44          |
# |    time_elapsed         | 5669        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.012216968 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0502     |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.46        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0177      |
# |    value_loss           | 7.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55        |
# |    ep_rew_mean          | 80.6        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 45          |
# |    time_elapsed         | 5799        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006926516 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0414     |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.6         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00715     |
# |    value_loss           | 11.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.85         |
# |    ep_rew_mean          | 79.4         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 46           |
# |    time_elapsed         | 5931         |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0072290814 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.039       |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.73         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00599      |
# |    value_loss           | 10.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.88        |
# |    ep_rew_mean          | 78.4        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 47          |
# |    time_elapsed         | 6066        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.017216153 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0423     |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.92        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0232      |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.1         |
# |    ep_rew_mean          | 78.2        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 48          |
# |    time_elapsed         | 6198        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.048436962 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0329     |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.86        |
# |    ep_rew_mean          | 79.3        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 49          |
# |    time_elapsed         | 6330        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.012679391 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0362     |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00534     |
# |    value_loss           | 25.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.64        |
# |    ep_rew_mean          | 80.4        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 50          |
# |    time_elapsed         | 6461        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.008689234 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0329     |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.23        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.000962    |
# |    value_loss           | 9.96        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.01         |
# |    ep_rew_mean          | 78.6         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 51           |
# |    time_elapsed         | 6591         |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0025788657 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0316      |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.85         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00497      |
# |    value_loss           | 8.95         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.11       |
# |    ep_rew_mean          | 82.5       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 52         |
# |    time_elapsed         | 6724       |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.01108196 |
# |    clip_fraction        | 0.0202     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0294    |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.3       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.00192    |
# |    value_loss           | 10         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.1          |
# |    ep_rew_mean          | 78.3         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 53           |
# |    time_elapsed         | 6854         |
# |    total_timesteps      | 217088       |
# | train/                  |              |
# |    approx_kl            | 0.0066939164 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0269      |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.746        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00658      |
# |    value_loss           | 10.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.89       |
# |    ep_rew_mean          | 79.2       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 54         |
# |    time_elapsed         | 6986       |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.03262825 |
# |    clip_fraction        | 0.0294     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0329    |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 15.2       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.00419    |
# |    value_loss           | 16.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.44        |
# |    ep_rew_mean          | 81          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 55          |
# |    time_elapsed         | 7118        |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.018326137 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0284     |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 30          |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00557     |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# ...
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.743       |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00137     |
# |    value_loss           | 5.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.83         |
# |    ep_rew_mean          | 79.6         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 184          |
# |    time_elapsed         | 23771        |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0019389382 |
# |    clip_fraction        | 0.00481      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0094      |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.372        |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | 0.000151     |
# |    value_loss           | 0.912        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.41        |
# |    ep_rew_mean          | 81          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 185         |
# |    time_elapsed         | 23902       |
# |    total_timesteps      | 757760      |
# | train/                  |             |
# |    approx_kl            | 0.007980794 |
# |    clip_fraction        | 0.00518     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00718    |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.194       |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.000719    |
# |    value_loss           | 5.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.76        |
# |    ep_rew_mean          | 80          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 186         |
# |    time_elapsed         | 24041       |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.011667588 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0117     |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.24        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.0266      |
# |    value_loss           | 4.52        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.89         |
# |    ep_rew_mean          | 79.1         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 187          |
# |    time_elapsed         | 24174        |
# |    total_timesteps      | 765952       |
# | train/                  |              |
# |    approx_kl            | 0.0105505865 |
# |    clip_fraction        | 0.00444      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00741     |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.34         |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | 0.00429      |
# |    value_loss           | 1.11         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.36        |
# |    ep_rew_mean          | 81.5        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 188         |
# |    time_elapsed         | 24300       |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.013799238 |
# |    clip_fraction        | 0.00659     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00759    |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.476       |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 5.34        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 7.31     |
# |    ep_rew_mean          | 73.2     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 189      |
# |    time_elapsed         | 24435    |
# |    total_timesteps      | 774144   |
# | train/                  |          |
# |    approx_kl            | 0.413343 |
# |    clip_fraction        | 0.0578   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0391  |
# |    explained_variance   | 0.948    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 7.94     |
# |    n_updates            | 1880     |
# |    policy_gradient_loss | -0.00168 |
# |    value_loss           | 5.81     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.07      |
# |    ep_rew_mean          | 78.6      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 190       |
# |    time_elapsed         | 24570     |
# |    total_timesteps      | 778240    |
# | train/                  |           |
# |    approx_kl            | 0.0692848 |
# |    clip_fraction        | 0.146     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.141    |
# |    explained_variance   | 0.552     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 33.9      |
# |    n_updates            | 1890      |
# |    policy_gradient_loss | -0.000507 |
# |    value_loss           | 63.4      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.4         |
# |    ep_rew_mean          | 77.2        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 191         |
# |    time_elapsed         | 24704       |
# |    total_timesteps      | 782336      |
# | train/                  |             |
# |    approx_kl            | 0.061906595 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.079      |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.74        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 27.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.21       |
# |    ep_rew_mean          | 78.1       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 192        |
# |    time_elapsed         | 24835      |
# |    total_timesteps      | 786432     |
# | train/                  |            |
# |    approx_kl            | 0.03670587 |
# |    clip_fraction        | 0.0813     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0796    |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 18.9       |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | -0.0046    |
# |    value_loss           | 19.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.65        |
# |    ep_rew_mean          | 80.4        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 193         |
# |    time_elapsed         | 24967       |
# |    total_timesteps      | 790528      |
# | train/                  |             |
# |    approx_kl            | 0.022870038 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.077      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.44        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.87        |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 194         |
# |    time_elapsed         | 25098       |
# |    total_timesteps      | 794624      |
# | train/                  |             |
# |    approx_kl            | 0.013426867 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.065      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.14        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.69        |
# |    ep_rew_mean          | 80          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 195         |
# |    time_elapsed         | 25235       |
# |    total_timesteps      | 798720      |
# | train/                  |             |
# |    approx_kl            | 0.015283172 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0529     |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.44        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.000134    |
# |    value_loss           | 8.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.8          |
# |    ep_rew_mean          | 79.6         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 196          |
# |    time_elapsed         | 25380        |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0052650673 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0589      |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.62         |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.000932    |
# |    value_loss           | 5.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.53        |
# |    ep_rew_mean          | 80.6        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 197         |
# |    time_elapsed         | 25529       |
# |    total_timesteps      | 806912      |
# | train/                  |             |
# |    approx_kl            | 0.016890736 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0651     |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.5        |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | 0.00229     |
# |    value_loss           | 34          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.88       |
# |    ep_rew_mean          | 79.4       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 198        |
# |    time_elapsed         | 25673      |
# |    total_timesteps      | 811008     |
# | train/                  |            |
# |    approx_kl            | 0.06858159 |
# |    clip_fraction        | 0.0446     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0469    |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 9.35       |
# |    n_updates            | 1970       |
# |    policy_gradient_loss | -0.0052    |
# |    value_loss           | 25.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.26       |
# |    ep_rew_mean          | 78         |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 199        |
# |    time_elapsed         | 25817      |
# |    total_timesteps      | 815104     |
# | train/                  |            |
# |    approx_kl            | 0.20619881 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.119     |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.64       |
# |    n_updates            | 1980       |
# |    policy_gradient_loss | -0.00246   |
# |    value_loss           | 5.55       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.92       |
# |    ep_rew_mean          | 79.2       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 200        |
# |    time_elapsed         | 25959      |
# |    total_timesteps      | 819200     |
# | train/                  |            |
# |    approx_kl            | 0.07477372 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.18      |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 6.4        |
# |    n_updates            | 1990       |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 44.6       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.34      |
# |    ep_rew_mean          | 81.6      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 201       |
# |    time_elapsed         | 26105     |
# |    total_timesteps      | 823296    |
# | train/                  |           |
# |    approx_kl            | 0.0315566 |
# |    clip_fraction        | 0.113     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.137    |
# |    explained_variance   | 0.852     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.06      |
# |    n_updates            | 2000      |
# |    policy_gradient_loss | -0.0142   |
# |    value_loss           | 15.7      |
# ---------------------------------------

# %%
# !tensorboard --logdir={os.path.join('logs/DOOM', 'PPO_1')}

# %% [markdown]
# <img src='image/Doom_Basic_1.png'/>
# <img src='image/Doom_Basic_2.png'/>

# %% [markdown]
# Remark:
# - We would like the ***Mean Reward keep going as higher as possible***, it ***reach highest reward at 150k timesteps around 80*** (time spend 1hr 18min).
# - Compare to the average reward -121 by taking random action before learning, ***the agent perform significantly better. It killed the monster very quickly***.

# %% [markdown]
# # 5. Load and Test the Best Saved Agent

# %%
# Import eval policy to test agent
from stable_baseline3.common.evaluation import evaluate_policy

# Reload model from disc
model = PPO_model.load(CHECKPOINT_DIR+'/best_model_1000000.zip')     # input the model name here

# Create rendered environment
env = VizDoomGym(render = True)

# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes = 20)

print(mean_reward)
# Out:
# 83.0

# %% [markdown]
# Remark:
# - ***Load the best saved agent*** during the 1 million timesteps process to evaluate the final performance of the agent. ***It killed the monster very quickly and received 83 rewards***.

# %% [markdown]
# ***End of Page***
